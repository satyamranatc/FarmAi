# %%
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPool2D
from tensorflow.keras.utils import  load_img,img_to_array
from tensorflow.keras.utils import image_dataset_from_directory as rfd

# %%
data = rfd(
    "./Dataset/Train",
    image_size=(128, 128),
    batch_size=32
)
# Out:
# Found 1216 files belonging to 4 classes.

# %%
classNames = data.class_names
classNames
# Out:
# ['Alluvial soil', 'Black Soil', 'Clay soil', 'Red soil']

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation="relu"),
    MaxPool2D(),

    Conv2D(64, (3, 3), activation="relu"),
    MaxPool2D(),

    Flatten(),

    Dense(128,activation="relu"),

    Dense(len(classNames),activation="softmax")

])

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
model.fit(
    data,
    epochs=10
)
# Out:
# Epoch 1/10
# /Users/satyamrana/Desktop/FarmAi/.venv/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 0.5740 - loss: 111.7161
# Epoch 2/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - accuracy: 0.8438 - loss: 0.4169
# Epoch 3/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.9350 - loss: 0.2251
# Epoch 4/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9597 - loss: 0.1453
# Epoch 5/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - accuracy: 0.9852 - loss: 0.0850
# Epoch 6/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - accuracy: 0.9885 - loss: 0.0624
# Epoch 7/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - accuracy: 0.9951 - loss: 0.0516
# Epoch 8/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - accuracy: 0.9951 - loss: 0.0401
# Epoch 9/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9967 - loss: 0.0276
# Epoch 10/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 0.9992 - loss: 0.0165

# %%
# Load new image
image = load_img(
    "Black_1.jpg",
    target_size=(128, 128)
)

# Convert image to numbers
image = img_to_array(image)

# Add one extra dimension
image = np.expand_dims(image, axis=0)

# Ask CNN to predict
prediction = model.predict(image)

# Find highest probability
result = np.argmax(prediction)
classNames[result]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 'Black Soil'
