# %%
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPool2D
from tensorflow.keras.utils import  load_img,img_to_array
from tensorflow.keras.utils import image_dataset_from_directory as rfd

# %%
data = rfd(
    "./Dataset/Train",
    image_size=(128, 128),
    batch_size=32
)
# Out:
# Found 1216 files belonging to 4 classes.

# %%
classNames = data.class_names
classNames
# Out:
# ['Alluvial soil', 'Black Soil', 'Clay soil', 'Red soil']

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation="relu"),
    MaxPool2D(),

    Conv2D(64, (3, 3), activation="relu"),
    MaxPool2D(),

    Flatten(),

    Dense(128,activation="relu"),

    Dense(len(classNames),activation="softmax")

])

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
model.fit(
    data,
    epochs=10
)
# Out:
# Epoch 1/10
# /Users/satyamrana/Documents/FarmAi/.venv/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 155ms/step - accuracy: 0.5658 - loss: 119.3487
# Epoch 2/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - accuracy: 0.8322 - loss: 0.7446
# Epoch 3/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - accuracy: 0.9021 - loss: 0.5175
# Epoch 4/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - accuracy: 0.9186 - loss: 0.3902
# Epoch 5/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - accuracy: 0.9523 - loss: 0.1669
# Epoch 6/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - accuracy: 0.9712 - loss: 0.0845
# Epoch 7/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - accuracy: 0.9860 - loss: 0.0585
# Epoch 8/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 205ms/step - accuracy: 0.9942 - loss: 0.0233
# Epoch 9/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 193ms/step - accuracy: 0.9844 - loss: 0.0651
# Epoch 10/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 221ms/step - accuracy: 0.9934 - loss: 0.0372

# %%
# Load new image
image = load_img(
    "Black_1.jpg",
    target_size=(128, 128)
)

# Convert image to numbers
image = img_to_array(image)

# Add one extra dimension
image = np.expand_dims(image, axis=0)

# Ask CNN to predict
prediction = model.predict(image)

# Find highest probability
result = np.argmax(prediction)
classNames[result]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 'Black Soil'

# %%
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
